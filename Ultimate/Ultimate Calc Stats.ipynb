# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
modes = ["Frankfurt","Wilshire-5000","Wilshire-5000-New"]
MODE = modes[0]
PATH = "C:/Users/Antonino/Desktop/Projekte/Finance/Stocks/" + MODE + "/"

# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Dataframe from CSV

# %%
# Reads a dataframe from the CSV file, changes index to date and returns it
def get_stock_df_from_csv(ticker):
    
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(PATH + ticker + '.csv', index_col=0)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# ## Get all Stocks Downloaded in List

# %%
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]

# tickers.remove('.ds_Store') MacOS Only
tickers.sort()
len(tickers)
# Out:
# 494

# %% [markdown]
# ## Add Daily Returns

# %%
# Shift provides the value from the previous day
# NaN is displayed because there was no previous day price for the 1st calculation
def add_daily_return_to_df(df):
    df['daily_return'] = (df['Close'] / df['Close'].shift(1)) - 1
    # Save data to a CSV file
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Cumulative Returns

# %%
def add_cum_return_to_df(df):
    df['cum_return'] = (1 + df['daily_return']).cumprod()
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Bollinger Bands

# %% [markdown]
# Bollinger Bands plot 2 lines using a moving average and the standard deviation defines how far apart the lines are. They also are used to define if prices are to high or low. When bands tighten it is believed a sharp price move in some direction. Prices tend to bounce off of the bands which provides potential market actions.
#
# A strong trend should be noted if the price moves outside the band. If prices go over the resistance line it is in overbought territory and if it breaks through support it is a sign of an oversold position.

# %%
# Here we will add a middle band (20 days), upper band (20 days + 1.96 std),
# and lower band (20 days - 1.96 std)
def add_bollinger_bands(df):
    df['middle_band'] = df['Close'].rolling(window=20).mean()
    df['upper_band'] = df['middle_band'] + 1.96 * df['Close'].rolling(window=20).std()
    df['lower_band'] = df['middle_band'] - 1.96 * df['Close'].rolling(window=20).std()
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Ichimoku Data to Dataframe

# %% [markdown]
# The Ichimoku (One Look) is considered an all in one indicator. It provides information on momentum, support and resistance. It is made up of 5 lines. If you are a short term trader you create 1 minute or 6 hour. Long term traders focus on day or weekly data.
#
#  - Conversion Line (Tenkan-sen) : Represents support, resistance and reversals. Used to measure short term trends.
#  - Baseline (Kijun-sen) : Represents support, resistance and confirms trend changes. Allows you to evaluate the strength of medium term trends. Called the baseline because it lags the price.
#  - Leading Span A (Senkou A) : Used to identify future areas of support and resistance
#  - Leading Span B (Senkou B) : Other line used to identify suture support and resistance
#  - Lagging Span (Chikou) : Shows possible support and resistance. It is used to confirm signals obtained from other lines.
#  - Cloud (Kumo) : Space between Span A and B. Represents the divergence in price evolution.
#
# Formulas
#
#  - Lagging Span = Price shifted back 26 periods
#  - Base Line = (Highest Value in period + Lowest value in period)/2 (26 Sessions)
#  - Conversion Line = (Highest Value in period + Lowest value in period)/2 (9 Sessions)
#  - Leading Span A = (Conversion Value + Base Value)/2 (26 Sessions)
#  - Leading Span B = (Conversion Value + Base Value)/2 (52 Sessions)

# %%
def add_Ichimoku(df):
    # Conversion
    hi_val = df['High'].rolling(window=9).max()
    low_val = df['Low'].rolling(window=9).min()
    df['Conversion'] = (hi_val + low_val) / 2

    # Baseline
    hi_val2 = df['High'].rolling(window=26).max()
    low_val2 = df['Low'].rolling(window=26).min()
    df['Baseline'] = (hi_val2 + low_val2) / 2

    # Spans
    df['SpanA'] = ((df['Conversion'] + df['Baseline']) / 2).shift(26)
    hi_val3 = df['High'].rolling(window=52).max()
    low_val3 = df['Low'].rolling(window=52).min()
    df['SpanB'] = ((hi_val3 + low_val3) / 2).shift(26)
    df['Lagging'] = df['Close'].shift(-26)

    return df

# %% [markdown]
# ## Add Daily, Cumulative Bollinger Bands & Ichimoku to Dataframes

# %%
i = 0
for x in tickers:
    try:
        print("Working on :", x)
        print("Status: ", i)
        new_df = get_stock_df_from_csv(x)
        new_df = add_daily_return_to_df(new_df)
        new_df = add_cum_return_to_df(new_df)
        new_df = add_bollinger_bands(new_df)
        new_df = add_Ichimoku(new_df)
        new_df.to_csv(PATH + x + '.csv')
        i += 1
    except Exception as ex:
        print(ex)
# Out:
# Working on : 02P_DE
# Status:  0
# Working on : 1COV_DE
# Status:  1
# Working on : 1U1_DE
# Status:  2
# Working on : 2GB_DE
# Status:  3
# Working on : 2HRA_DE
# Status:  4
# Working on : 2INV_DE
# Status:  5
# Working on : 333_DE
# Status:  6
# Working on : 4DS_DE
# Status:  7
# Working on : 5UH_DE
# Status:  8
# Working on : 690D_DE
# Status:  9
# Working on : 8S9_DE
# Status:  10
# Working on : 8TRA_DE
# Status:  11
# Working on : 99SC_DE
# Status:  12
# Working on : A1OS_DE
# Status:  13
# Working on : A2QRHL_DE
# Status:  14
# Working on : A3CMGN_DE
# Status:  15
# Working on : A4Y_DE
# Status:  16
# Working on : A6T_DE
# Status:  17
# Working on : A7A_DE
# Status:  18
# Working on : A8A_DE
# Status:  19
# Working on : AAA_DE
# Status:  20
# Working on : AAD_DE
# Status:  21
# Working on : AAG_DE
# Status:  22
# Working on : AAH_DE
# Status:  23
# Working on : AAQ1_DE
# Status:  24
# Working on : AB1_DE
# Status:  25
# Working on : ABA_DE
# Status:  26
# Working on : ACT_DE
# Status:  27
# Working on : ACWN_DE
# Status:  28
# Working on : ACX_DE
# Status:  29
# Working on : ADJ_DE
# Status:  30
# Working on : ADL_DE
# Status:  31
# Working on : ADN1_DE
# Status:  32
# Working on : ADS_DE
# Status:  33
# Working on : ADV_DE
# Status:  34
# Working on : AEIN_DE
# Status:  35
# Working on : AFX_DE
# Status:  36
# Working on : AG1_DE
# Status:  37
# Working on : AIR_DE
# Status:  38
# Working on : AIXA_DE
# Status:  39
# Working on : ALG_DE
# Status:  40
# Working on : ALV_DE
# Status:  41
# Working on : AM3D_DE
# Status:  42
# Working on : AMA1_DE
# Status:  43
# Working on : AOF_DE
# Status:  44
# Working on : AOX_DE
# Status:  45
# Working on : APM_DE
# Status:  46
# Working on : APPH_DE
# Status:  47
# Working on : ARL_DE
# Status:  48
# Working on : ART_DE
# Status:  49
# Working on : ASL_DE
# Status:  50
# Working on : AT1_DE
# Status:  51
# Working on : AVES_DE
# Status:  52
# Working on : B4B3_DE
# Status:  53
# Working on : B4B_DE
# Status:  54
# Working on : B5A_DE
# Status:  55
# Working on : B7E_DE
# Status:  56
# Working on : B8F_DE
# Status:  57
# Working on : BAS_DE
# Status:  58
# Working on : BAYN_DE
# Status:  59
# Working on : BBZA_DE
# Status:  60
# Working on : BC8_DE
# Status:  61
# Working on : BDT_DE
# Status:  62
# Working on : BEI_DE
# Status:  63
# Working on : BEZ_DE
# Status:  64
# Working on : BFSA_DE
# Status:  65
# Working on : BIJ_DE
# Status:  66
# Working on : BIKE_DE
# Status:  67
# Working on : BIO3_DE
# Status:  68
# Working on : BIO_DE
# Status:  69
# Working on : BKHT_DE
# Status:  70
# Working on : BMW3_DE
# Status:  71
# Working on : BMW_DE
# Status:  72
# Working on : BNN_DE
# Status:  73
# Working on : BNR_DE
# Status:  74
# Working on : BNT1_DE
# Status:  75
# Working on : BOSS_DE
# Status:  76
# Working on : BSL_DE
# Status:  77
# Working on : BSS_DE
# Status:  78
# Working on : BST_DE
# Status:  79
# Working on : BTBB_DE
# Status:  80
# Working on : BVB_DE
# Status:  81
# Working on : BYW6_DE
# Status:  82
# Working on : BYW_DE
# Status:  83
# Working on : C0M_DE
# Status:  84
# Working on : C1V_DE
# Status:  85
# Working on : C3RY_DE
# Status:  86
# Working on : CAP_DE
# Status:  87
# Working on : CBK_DE
# Status:  88
# Working on : CC1_DE
# Status:  89
# Working on : CCAP_DE
# Status:  90
# Working on : CE2_DE
# Status:  91
# Working on : CEA_DE
# Status:  92
# Working on : CEC1_DE
# Status:  93
# Working on : CEC_DE
# Status:  94
# Working on : CHX_DE
# Status:  95
# Working on : CLIQ_DE
# Status:  96
# Working on : CNWK_DE
# Status:  97
# Working on : COK_DE
# Status:  98
# Working on : CON_DE
# Status:  99
# Working on : COP_DE
# Status:  100
# Working on : CPX_DE
# Status:  101
# Working on : CRIN_DE
# Status:  102
# Working on : CSH_DE
# Status:  103
# Working on : CSQ_DE
# Status:  104
# Working on : CWC_DE
# Status:  105
# Working on : CYR_DE
# Status:  106
# Working on : D6H_DE
# Status:  107
# Working on : DAI_DE
# Status:  108
# Working on : DAM_DE
# Status:  109
# Working on : DAR_DE
# Status:  110
# Working on : DB1_DE
# Status:  111
# Working on : DBAN_DE
# Status:  112
# Working on : DBD_DE
# Status:  113
# Working on : DBK_DE
# Status:  114
# Working on : DEQ_DE
# Status:  115
# Working on : DEX_DE
# Status:  116
# Working on : DEZ_DE
# Status:  117
# Working on : DFTK_DE
# Status:  118
# Working on : DFV_DE
# Status:  119
# Working on : DGR_DE
# Status:  120
# Working on : DHER_DE
# Status:  121
# Working on : DIC_DE
# Status:  122
# Working on : DIE_DE
# Status:  123
# Working on : DIS_DE
# Status:  124
# Working on : DKG_DE
# Status:  125
# Working on : DLX_DE
# Status:  126
# Working on : DMP_DE
# Status:  127
# Working on : DMRE_DE
# Status:  128
# Working on : DPW_DE
# Status:  129
# Working on : DR0_DE
# Status:  130
# Working on : DRE2_DE
# Status:  131
# Working on : DRW3_DE
# Status:  132
# Working on : DRW8_DE
# Status:  133
# Working on : DTD2_DE
# Status:  134
# Working on : DTE_DE
# Status:  135
# Working on : DUE_DE
# Status:  136
# Working on : DWNI_DE
# Status:  137
# Working on : DWS_DE
# Status:  138
# Working on : E4C_DE
# Status:  139
# Working on : EBK_DE
# Status:  140
# Working on : ECK_DE
# Status:  141
# Working on : ECX_DE
# Status:  142
# Working on : ED4_DE
# Status:  143
# Working on : EDL_DE
# Status:  144
# Working on : EIN3_DE
# Status:  145
# Working on : EIS_DE
# Status:  146
# Working on : EKT_DE
# Status:  147
# Working on : ELB_DE
# Status:  148
# Working on : ELG_DE
# Status:  149
# Working on : ELN_DE
# Status:  150
# Working on : EMH_DE
# Status:  151
# Working on : ENR_DE
# Status:  152
# Working on : EOAN_DE
# Status:  153
# Working on : EQS_DE
# Status:  154
# Working on : ERO1_DE
# Status:  155
# Working on : ERWE_DE
# Status:  156
# Working on : ESY_DE
# Status:  157
# Working on : EUCA_DE
# Status:  158
# Working on : EUZ_DE
# Status:  159
# Working on : EVD_DE
# Status:  160
# Working on : EVK_DE
# Status:  161
# Working on : EVT_DE
# Status:  162
# Working on : EXC_DE
# Status:  163
# Working on : EXJ_DE
# Status:  164
# Working on : EXL_DE
# Status:  165
# Working on : F3C_DE
# Status:  166
# Working on : FAA_DE
# Status:  167
# Working on : FC9_DE
# Status:  168
# Working on : FEV_DE
# Status:  169
# Working on : FIE_DE
# Status:  170
# Working on : FKEK_DE
# Status:  171
# Working on : FME_DE
# Status:  172
# Working on : FNG_DE
# Status:  173
# Working on : FNTN_DE
# Status:  174
# Working on : FPE3_DE
# Status:  175
# Working on : FPE_DE
# Status:  176
# Working on : FPH_DE
# Status:  177
# Working on : FQT_DE
# Status:  178
# Working on : FRA_DE
# Status:  179
# Working on : FRE_DE
# Status:  180
# Working on : FRS_DE
# Status:  181
# Working on : FRU_DE
# Status:  182
# Working on : FSNT _DE
# Status:  183
# Working on : FTK_DE
# Status:  184
# Working on : FVI_DE
# Status:  185
# Working on : FYB_DE
# Status:  186
# Working on : G1A_DE
# Status:  187
# Working on : G24_DE
# Status:  188
# Working on : G7B_DE
# Status:  189
# Working on : GBF_DE
# Status:  190
# Working on : GFG_DE
# Status:  191
# Working on : GFT_DE
# Status:  192
# Working on : GGS_DE
# Status:  193
# Working on : GIB_DE
# Status:  194
# Working on : GIL_DE
# Status:  195
# Working on : GKS_DE
# Status:  196
# Working on : GLJ_DE
# Status:  197
# Working on : GME_DE
# Status:  198
# Working on : GMM_DE
# Status:  199
# Working on : GSC1_DE
# Status:  200
# Working on : GTY_DE
# Status:  201
# Working on : GWI2_DE
# Status:  202
# Working on : GXI_DE
# Status:  203
# Working on : GYC_DE
# Status:  204
# Working on : H24_DE
# Status:  205
# Working on : H2O_DE
# Status:  206
# Working on : H5E_DE
# Status:  207
# Working on : H9Y_DE
# Status:  208
# Working on : HAB_DE
# Status:  209
# Working on : HAW_DE
# Status:  210
# Working on : HBD1_DE
# Status:  211
# Working on : HBH_DE
# Status:  212
# Working on : HBM_DE
# Status:  213
# Working on : HDD_DE
# Status:  214
# Working on : HEI_DE
# Status:  215
# Working on : HEMP_DE
# Status:  216
# Working on : HEN3_DE
# Status:  217
# Working on : HEN_DE
# Status:  218
# Working on : HETA_DE
# Status:  219
# Working on : HFG_DE
# Status:  220
# Working on : HHFA_DE
# Status:  221
# Working on : HLAG_DE
# Status:  222
# Working on : HLE_DE
# Status:  223
# Working on : HLG_DE
# Status:  224
# Working on : HNL_DE
# Status:  225
# Working on : HNR1_DE
# Status:  226
# Working on : HOC_DE
# Status:  227
# Working on : HOT_DE
# Status:  228
# Working on : HP3_DE
# Status:  229
# Working on : HPBK_DE
# Status:  230
# Working on : HRPK_DE
# Status:  231
# Working on : HXCK_DE
# Status:  232
# Working on : HYQ_DE
# Status:  233
# Working on : I7N_DE
# Status:  234
# Working on : IBU_DE
# Status:  235
# Working on : ICP_DE
# Status:  236
# Working on : IFS_DE
# Status:  237
# Working on : IFX_DE
# Status:  238
# Working on : ILM1_DE
# Status:  239
# Working on : INH_DE
# Status:  240
# Working on : INS_DE
# Status:  241
# Working on : IPOK_DE
# Status:  242
# Working on : IQL_DE
# Status:  243
# Working on : IS7_DE
# Status:  244
# Working on : ISH2_DE
# Status:  245
# Working on : ITN_DE
# Status:  246
# Working on : IUR_DE
# Status:  247
# Working on : IVU_DE
# Status:  248
# Working on : IVX_DE
# Status:  249
# Working on : IXX_DE
# Status:  250
# Working on : JB7_DE
# Status:  251
# Working on : JEN_DE
# Status:  252
# Working on : JST_DE
# Status:  253
# Working on : JUN3_DE
# Status:  254
# Working on : K1R_DE
# Status:  255
# Working on : KA8_DE
# Status:  256
# Working on : KBX_DE
# Status:  257
# Working on : KCC_DE
# Status:  258
# Working on : KCO_DE
# Status:  259
# Working on : KGX_DE
# Status:  260
# Working on : KRN_DE
# Status:  261
# Working on : KSB3_DE
# Status:  262
# Working on : KSB_DE
# Status:  263
# Working on : KSC_DE
# Status:  264
# Working on : KTA_DE
# Status:  265
# Working on : KTEK_DE
# Status:  266
# Working on : KU2_DE
# Status:  267
# Working on : KWG_DE
# Status:  268
# Working on : KWS_DE
# Status:  269
# Working on : L1OA_DE
# Status:  270
# Working on : LEG_DE
# Status:  271
# Working on : LEI_DE
# Status:  272
# Working on : LEO_DE
# Status:  273
# Working on : LHA_DE
# Status:  274
# Working on : LIN_DE
# Status:  275
# Working on : LNSX_DE
# Status:  276
# Working on : LPK_DE
# Status:  277
# Working on : LRS1_DE
# Status:  278
# Working on : LSX_DE
# Status:  279
# Working on : LUM_DE
# Status:  280
# Working on : LXS_DE
# Status:  281
# Working on : M0Y_DE
# Status:  282
# Working on : M3BK_DE
# Status:  283
# Working on : M3V_DE
# Status:  284
# Working on : M5Z_DE
# Status:  285
# Working on : M7U_DE
# Status:  286
# Working on : M8G_DE
# Status:  287
# Working on : MAK_DE
# Status:  288
# Working on : MBB_DE
# Status:  289
# Working on : MBH3_DE
# Status:  290
# Working on : MDG1_DE
# Status:  291
# Working on : MDN_DE
# Status:  292
# Working on : MED_DE
# Status:  293
# Working on : MF6_DE
# Status:  294
# Working on : MFL2_DE
# Status:  295
# Working on : ML2_DE
# Status:  296
# Working on : MLL_DE
# Status:  297
# Working on : MLP_DE
# Status:  298
# Working on : MNV6_DE
# Status:  299
# Working on : MOR_DE
# Status:  300
# Working on : MPCK_DE
# Status:  301
# Working on : MPRK_DE
# Status:  302
# Working on : MPSC_DE
# Status:  303
# Working on : MRK_DE
# Status:  304
# Working on : MRX_DE
# Status:  305
# Working on : MSAG_DE
# Status:  306
# Working on : MSH_DE
# Status:  307
# Working on : MTX_DE
# Status:  308
# Working on : MUM_DE
# Status:  309
# Working on : MUV2_DE
# Status:  310
# Working on : MUX_DE
# Status:  311
# Working on : MVV1_DE
# Status:  312
# Working on : MXHN_DE
# Status:  313
# Working on : MZX_DE
# Status:  314
# Working on : N4G_DE
# Status:  315
# Working on : NA9_DE
# Status:  316
# Working on : NBG6_DE
# Status:  317
# Working on : NC5A_DE
# Status:  318
# Working on : NDA_DE
# Status:  319
# Working on : NDX1_DE
# Status:  320
# Working on : NEM_DE
# Status:  321
# Working on : NFN_DE
# Status:  322
# Working on : NOEJ_DE
# Status:  323
# Working on : NSN_DE
# Status:  324
# Working on : NTG_DE
# Status:  325
# Working on : NUVA_DE
# Status:  326
# Working on : NVM_DE
# Status:  327
# Working on : NWO_DE
# Status:  328
# Working on : NWX_DE
# Status:  329
# Working on : NXU_DE
# Status:  330
# Working on : O2C_DE
# Status:  331
# Working on : O2D_DE
# Status:  332
# Working on : O4B_DE
# Status:  333
# Working on : O5G_DE
# Status:  334
# Working on : O5H_DE
# Status:  335
# Working on : OBS_DE
# Status:  336
# Working on : OHB_DE
# Status:  337
# Working on : OLG_DE
# Status:  338
# Working on : OMAX_DE
# Status:  339
# Working on : OMR_DE
# Status:  340
# Working on : OSP2_DE
# Status:  341
# Working on : OTA_DE
# Status:  342
# Working on : PA8_DE
# Status:  343
# Working on : PAH3_DE
# Status:  344
# Working on : PAL_DE
# Status:  345
# Working on : PAT_DE
# Status:  346
# Working on : PBB_DE
# Status:  347
# Working on : PBY_DE
# Status:  348
# Working on : PCZ_DE
# Status:  349
# Working on : PFV_DE
# Status:  350
# Working on : PGN_DE
# Status:  351
# Working on : PIT_DE
# Status:  352
# Working on : PMAG_DE
# Status:  353
# Working on : PNE3_DE
# Status:  354
# Working on : PSAN_DE
# Status:  355
# Working on : PSG_DE
# Status:  356
# Working on : PSM_DE
# Status:  357
# Working on : PUM_DE
# Status:  358
# Working on : PUZ_DE
# Status:  359
# Working on : PWO_DE
# Status:  360
# Working on : PZS_DE
# Status:  361
# Working on : QIA_DE
# Status:  362
# Working on : QSC_DE
# Status:  363
# Working on : RAA_DE
# Status:  364
# Working on : RCMN_DE
# Status:  365
# Working on : RHK_DE
# Status:  366
# Working on : RHM_DE
# Status:  367
# Working on : RIB_DE
# Status:  368
# Working on : RKB_DE
# Status:  369
# Working on : RRTL_DE
# Status:  370
# Working on : RSL2_DE
# Status:  371
# Working on : RTC_DE
# Status:  372
# Working on : RTML_DE
# Status:  373
# Working on : RTV_DE
# Status:  374
# Working on : RWE_DE
# Status:  375
# Working on : RY8_DE
# Status:  376
# Working on : S92_DE
# Status:  377
# Working on : S9I_DE
# Status:  378
# Working on : SAE_DE
# Status:  379
# Working on : SANT_DE
# Status:  380
# Working on : SAP_DE
# Status:  381
# Working on : SAX_DE
# Status:  382
# Working on : SBE_DE
# Status:  383
# Working on : SBS_DE
# Status:  384
# Working on : SCE_DE
# Status:  385
# Working on : SCM_DE
# Status:  386
# Working on : SDF_DE
# Status:  387
# Working on : SEN_DE
# Status:  388
# Working on : SF3_DE
# Status:  389
# Working on : SFQ_DE
# Status:  390
# Working on : SFX_DE
# Status:  391
# Working on : SGF_DE
# Status:  392
# Working on : SGL_DE
# Status:  393
# Working on : SGU_DE
# Status:  394
# Working on : SHA_DE
# Status:  395
# Working on : SHF_DE
# Status:  396
# Working on : SHL_DE
# Status:  397
# Working on : SIE_DE
# Status:  398
# Working on : SIM_DE
# Status:  399
# Working on : SIS_DE
# Status:  400
# Working on : SIX2_DE
# Status:  401
# Working on : SIX3_DE
# Status:  402
# Working on : SJJ_DE
# Status:  403
# Working on : SKB_DE
# Status:  404
# Working on : SLT_DE
# Status:  405
# Working on : SMHN_DE
# Status:  406
# Working on : SNG_DE
# Status:  407
# Working on : SNH_DE
# Status:  408
# Working on : SOW_DE
# Status:  409
# Working on : SPAC_DE
# Status:  410
# Working on : SPM_DE
# Status:  411
# Working on : SRT3_DE
# Status:  412
# Working on : SRT_DE
# Status:  413
# Working on : STM_DE
# Status:  414
# Working on : STO3_DE
# Status:  415
# Working on : SUR_DE
# Status:  416
# Working on : SUSE5A_DE
# Status:  417
# Working on : SWA_DE
# Status:  418
# Working on : SY1_DE
# Status:  419
# Working on : SYAB_DE
# Status:  420
# Working on : SYT_DE
# Status:  421
# Working on : SYZ_DE
# Status:  422
# Working on : SZG_DE
# Status:  423
# Working on : SZU_DE
# Status:  424
# Working on : TCU_DE
# Status:  425
# Working on : TEG_DE
# Status:  426
# Working on : TGHN_DE
# Status:  427
# Working on : TGT_DE
# Status:  428
# Working on : TIMA_DE
# Status:  429
# Working on : TIS_DE
# Status:  430
# Working on : TKA_DE
# Status:  431
# Working on : TLG_DE
# Status:  432
# Working on : TLIK_DE
# Status:  433
# Working on : TLX_DE
# Status:  434
# Working on : TMV_DE
# Status:  435
# Working on : TPE_DE
# Status:  436
# Working on : TTK_DE
# Status:  437
# Working on : TTO_DE
# Status:  438
# Working on : TTR1_DE
# Status:  439
# Working on : TUF_DE
# Status:  440
# Working on : TVD6_DE
# Status:  441
# Working on : ULC_DE
# Status:  442
# Working on : UN01_DE
# Status:  443
# Working on : UPR_DE
# Status:  444
# Working on : USE_DE
# Status:  445
# Working on : UTDI_DE
# Status:  446
# Working on : UUU_DE
# Status:  447
# Working on : UZU_DE
# Status:  448
# Working on : V3S_DE
# Status:  449
# Working on : V3V_DE
# Status:  450
# Working on : V6C_DE
# Status:  451
# Working on : VAO_DE
# Status:  452
# Working on : VAR1_DE
# Status:  453
# Working on : VBK_DE
# Status:  454
# Working on : VBX_DE
# Status:  455
# Working on : VG0K_DE
# Status:  456
# Working on : VH2_DE
# Status:  457
# Working on : VIB3_DE
# Status:  458
# Working on : VMR1_DE
# Status:  459
# Working on : VNA_DE
# Status:  460
# Working on : VOS_DE
# Status:  461
# Working on : VOW3_DE
# Status:  462
# Working on : VOW_DE
# Status:  463
# Working on : VQT_DE
# Status:  464
# Working on : VSC_DE
# Status:  465
# Working on : VTSC_DE
# Status:  466
# Working on : VTWR_DE
# Status:  467
# Working on : VVV3_DE
# Status:  468
# Working on : WAC_DE
# Status:  469
# Working on : WAF_DE
# Status:  470
# Working on : WBAH_DE
# Status:  471
# Working on : WCH_DE
# Status:  472
# Working on : WCMK_DE
# Status:  473
# Working on : WDI_DE
# Status:  474
# Working on : WDL_DE
# Status:  475
# Working on : WEW_DE
# Status:  476
# Working on : WIG1_DE
# Status:  477
# Working on : WL6_DE
# Status:  478
# Working on : WSU_DE
# Status:  479
# Working on : WTB3_DE
# Status:  480
# Working on : WTB_DE
# Status:  481
# Working on : WUG3_DE
# Status:  482
# Working on : WUG_DE
# Status:  483
# Working on : WUW_DE
# Status:  484
# Working on : WWG_DE
# Status:  485
# Working on : YMO_DE
# Status:  486
# Working on : YOC_DE
# Status:  487
# Working on : YOU_DE
# Status:  488
# Working on : YSN_DE
# Status:  489
# Working on : ZAL_DE
# Status:  490
# Working on : ZEF_DE
# Status:  491
# Working on : ZIL2_DE
# Status:  492
# Working on : ZO1_DE
# Status:  493

# %%
# It is always better to test your results using one stock
ticker = "BMW_DE"
try:
    print("Working on : ", ticker)
    new_df = get_stock_df_from_csv(ticker)
    new_df = add_daily_return_to_df(new_df)
    new_df = add_cum_return_to_df(new_df)
    new_df = add_bollinger_bands(new_df)
    new_df = add_Ichimoku(new_df)
    new_df.to_csv(PATH + 'A' + '.csv')
    print(new_df)
except Exception as ex:
    print(ex)
# Out:
# Working on :  BMW_DE
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2017-03-23  65.550248  65.771460  64.934012  65.637154  1391640        0.0
# 2017-03-24  65.889963  66.166479  65.131518  66.111176  1565883        0.0
# 2017-03-27  65.652949  65.953171  65.139417  65.953171  1424345        0.0
# 2017-03-28  66.395595  66.972326  65.953170  66.743217  1719210        0.0
# 2017-03-29  66.917016  67.414750  66.482493  67.003922  1708850        0.0
# ...               ...        ...        ...        ...      ...        ...
# 2022-03-17  79.339996  79.400002  75.510002  76.669998  2207957        0.0
# 2022-03-18  76.199997  76.660004  74.750000  75.900002  4736344        0.0
# 2022-03-21  76.239998  77.970001  75.739998  77.440002  1686583        0.0
# 2022-03-22  78.349998  79.760002  77.349998  79.059998  1732509        0.0
# 2022-03-23  80.339996  80.800003  77.849998  78.260002  1942435        0.0
#
#             Stock Splits  daily_return  cum_return  middle_band  upper_band  \
# Date
# 2017-03-23             0           NaN         NaN          NaN         NaN
# 2017-03-24             0      0.007222    1.007222          NaN         NaN
# 2017-03-27             0     -0.002390    1.004815          NaN         NaN
# 2017-03-28             0      0.011979    1.016851          NaN         NaN
# 2017-03-29             0      0.003906    1.020823          NaN         NaN
# ...                  ...           ...         ...          ...         ...
# 2022-03-17             0     -0.022066    1.168088    80.522999   96.110079
# 2022-03-18             0     -0.010043    1.156357    79.548999   93.649094
# 2022-03-21             0      0.020290    1.179820    78.806499   91.638513
# 2022-03-22             0      0.020919    1.204501    78.212999   89.768583
# 2022-03-23             0     -0.010119    1.192313    77.544999   87.311494
#
#             lower_band  Conversion  Baseline      SpanA      SpanB    Lagging
# Date
# 2017-03-23         NaN         NaN       NaN        NaN        NaN  68.655136
# 2017-03-24         NaN         NaN       NaN        NaN        NaN  68.971146
# 2017-03-27         NaN         NaN       NaN        NaN        NaN  70.393227
# 2017-03-28         NaN         NaN       NaN        NaN        NaN  71.017372
# 2017-03-29         NaN         NaN       NaN        NaN        NaN  70.732948
# ...                ...         ...       ...        ...        ...        ...
# 2022-03-17   64.935919   73.490002     82.59  93.339998  91.889999        NaN
# 2022-03-18   65.448905   74.100002     82.59  93.339998  91.889999        NaN
# 2022-03-21   65.974486   74.810001     82.59  93.567499  91.889999        NaN
# 2022-03-22   66.657416   74.990002     82.59  93.567499  91.889999        NaN
# 2022-03-23   67.778505   76.250000     82.59  93.567499  91.889999        NaN
#
# [1267 rows x 17 columns]
